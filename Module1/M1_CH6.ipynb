# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakData2026/AI_IN_DATA_SCIENCE/blob/main/Module1/M1_CH6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
def add(a,b):#a,b is parameter
  return a+b#body
(add(1,2))#arguments
(add(2,3))
# Out:
# 5

# %%
def add(a,b):#a,b is parameter
  print(a+b)#body
(add(1,2))#arguments
(add(2,3))
# Out:
# 3
# 5

# %%
def add(a,b):#a,b is parameter
  return a+b#body
first=add(3,3)
print(first)
# Out:
# 6

# %%
def hello():
  print("sarthak")
(hello())
# Out:
# sarthak

# %%
def juice(fruit):
  return fruit + "juice"
juice('apple')
# Out:
# 'applejuice'

# %%
def calc(a,b):
  add=a+b
  sub=a-b
  mul=a*b
  div=a//b
  pow=a**b
  return add,sub,mul,div,pow
calc(1,2)
# Out:
# (3, -1, 2, 0, 1)

# %%
def avg(a,b,c):
   add=a+b+c
   avg=add/3
   print(avg)
avg(1,2,3)
# Out:
# 2.0

# %%
def avg(a,b,c=9):#default parameter
   add=a+b+c
   avg=add/3
   print(avg)
avg(1,2)
# Out:
# 4.0

# %%
def avg(a,b,c=9):#default parameter
   add=a+b+c
   avg=add/3
   print(avg)
avg(1,2,10)
# Out:
# 4.333333333333333

# %%
def avg(a,b,c=9):#default parameter
   add=a+b+c
   avg=add/3
   print(avg)
avg(1,2)

# %%
def avg(a=7,b,c=9):#default parameter
   add=a+b+c
   avg=add/3
   print(avg)
avg(1,2)

# %%
def fact(n=6):
  fac=1
  for i in range(1,n+1):
    fac=fac*i
  return fac
fact(3)
# Out:
# 6

# %%
sq=lambda n:n*n
print(sq(2))
# Out:
# 4

# %% [markdown]
# 1.default argument
# 2.keyword arg

# %%
def avg(a,b,c=9):#default parameter
   add=a+b+c
   avg=add/3
   print(avg)
