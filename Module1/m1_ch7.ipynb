# %% [markdown]
# <a href="https://colab.research.google.com/github/SarthakData2026/AI_IN_DATA_SCIENCE/blob/main/Module1/m1_ch7.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# file handling

# %%
from google.colab import files
upload=files.upload()
# Out:
#      <input type="file" id="files-ed3451cf-0fb3-4f07-a811-0290f1063f68" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-ed3451cf-0fb3-4f07-a811-0290f1063f68">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %% [markdown]
# ##read in file

# %%
f=open("sarthak_txt.txt","r")
data=f.read()
print(type(data))
print(data)
f.close()
# Out:
# <class 'str'>
# my name is Sarthak
# I live in greater Noida
# I am 21 years old

# %%
f=open("sarthak_txt.txt","r")
print(f)
# Out:
# <_io.TextIOWrapper name='sarthak_txt.txt' mode='r' encoding='utf-8'>

# %%
f=open("sarthak_txt.txt","r")
data=f.read(80000)
print(type(data))
print(data)
f.close()
# Out:
# <class 'str'>
# my name is Sarthak
# I live in greater Noida
# I am 21 years old

# %%
f=open("sarthak_txt.txt","r")
line1=f.readline()
print(line1)
line2=f.readline()
print(line2)
line3=f.readline()
print(line3)
data=f.read()
#print(type(data))
print(data)
f.close()
# Out:
# my name is Sarthak
#
# I live in greater Noida
#
# I am 21 years old

# %%
f=open("sarthak_txt.txt","r")
line1=f.readline()
print(line1)
line2=f.readline()
print(line2)
#line3=f.readline()
#print(line3)
data=f.read()
#print(type(data))
print(data)
f.close()
# Out:
# my name is Sarthak
#
# I live in greater Noida
#
# I am 21 years old

# %%
f=open("sarthak_txt.txt","r")
line1=f.readline().strip()
print(line1)
line2=f.readline().strip()#remove /n
print(line2)
line3=f.readline()
print(line3)

f.close()
# Out:
# my name is Sarthak
# I live in greater Noida
# I am 21 years old

# %%
f=open("sarthak_txt.txt","r")
line1=f.readline()
print(line1,end='')
line2=f.readline() #remove /n
print(line2,end="")
line3=f.readline()
print(line3)

f.close()
# Out:
# my name is Sarthak
# I live in greater Noida
# I am 21 years old

# %% [markdown]
# ##write

# %%
f=open("sarthak_txt.txt","w")
data=f.write("/nhello everyone")
data=f.write("/nhello how are you ")
print(data)


f.close()
# Out:
# 20

# %%
f=open("sarthak_txt.txt","r")
data=f.read()
#print(type(data))
print(data)
f.close()
# Out:
# /nhello everyone/nhello how are you

# %%
f=open("check.txt","w")
data=f.write("\nhello everyone")
data=f.write("\nhello how are you ")
print(data)


f.close()
# Out:
# 19

# %% [markdown]
# ##append

# %%
f=open("sarthak_txt.txt","a")
data=f.write("hello world" )
data=f.write("python" )

print(data)


f.close()
# Out:
# 6

# %%
f=open("sarthak_txt.txt","r")
data=f.read()
#print(type(data))
print(data)
f.close()
# Out:
# /nhello everyone/nhello how are you hello worldpythonhello worldpython

# %%
with open ("sarthak_txt.txt","r") as f :

  print(f.read())
# Out:
# /nhello everyone/nhello how are you hello worldpythonhello worldpython
